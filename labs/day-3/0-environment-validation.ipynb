# %% [markdown]
# # Environment Validation Notebook
#
# This notebook validates that:
#
# - Python version is **3.11.x** (any patch version is fine, e.g. 3.11.0 or 3.11.9)
# - All critical LangChain ecosystem packages match expected versions
# - LangChain execution works end-to-end
# - Verbose callbacks work
# - Prompt + LLM pipeline runs successfully
#
# Run cells **top to bottom**, then continue with:
#
# - `1-Building-a-simple-AI-agent-using-LangChain.ipynb`
# - `2-Connecting-AI-agents-to-external-APIs.ipynb`
# - `3-langchain-vs-langgraph.ipynb`

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\25-trainings\2-confirmed\30-06-25-agentic-ai-acadwizz\venv\lib\site-packages (24.0)
# Collecting pip
#   Using cached pip-26.1.2-py3-none-any.whl.metadata (4.6 kB)
# Using cached pip-26.1.2-py3-none-any.whl (1.8 MB)
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 24.0
#     Uninstalling pip-24.0:
#       Successfully uninstalled pip-24.0
# Successfully installed pip-26.1.2
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install -r requirements.txt
# Out:
# Collecting langchain==1.2.0 (from -r requirements.txt (line 10))
#   Using cached langchain-1.2.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting langchain-classic==1.0.0 (from -r requirements.txt (line 11))
#   Using cached langchain_classic-1.0.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting langchain-core==1.2.2 (from -r requirements.txt (line 12))
#   Using cached langchain_core-1.2.2-py3-none-any.whl.metadata (3.7 kB)
# Collecting langchain-community==0.4.1 (from -r requirements.txt (line 13))
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting langchain-openai==1.1.5 (from -r requirements.txt (line 14))
#   Using cached langchain_openai-1.1.5-py3-none-any.whl.metadata (2.6 kB)
# Collecting langchain-text-splitters==1.1.0 (from -r requirements.txt (line 17))
#   Using cached langchain_text_splitters-1.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting langgraph==1.0.5 (from -r requirements.txt (line 23))
#   Using cached langgraph-1.0.5-py3-none-any.whl.metadata (7.4 kB)
# Collecting langgraph-prebuilt==1.0.5 (from -r requirements.txt (line 24))
#   Using cached langgraph_prebuilt-1.0.5-py3-none-any.whl.metadata (5.2 kB)
# Collecting langgraph-checkpoint==3.0.1 (from -r requirements.txt (line 25))
#   Using cached langgraph_checkpoint-3.0.1-py3-none-any.whl.metadata (4.7 kB)
# Collecting openai==2.13.0 (from -r requirements.txt (line 30))
#   Using cached openai-2.13.0-py3-none-any.whl.metadata (29 kB)
# Collecting tiktoken==0.12.0 (from -r requirements.txt (line 31))
#   Using cached tiktoken-0.12.0-cp311-cp311-win_amd64.whl.metadata (6.9 kB)
# Requirement already satisfied: httpx==0.28.1 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from -r requirements.txt (line 36)) (0.28.1)
# Collecting aiohttp==3.13.2 (from -r requirements.txt (line 37))
#   Using cached aiohttp-3.13.2-cp311-cp311-win_amd64.whl.metadata (8.4 kB)
# Collecting anyio==4.12.0 (from -r requirements.txt (line 38))
#   Using cached anyio-4.12.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting pydantic==2.12.5 (from -r requirements.txt (line 43))
#   Using cached pydantic-2.12.5-py3-none-any.whl.metadata (90 kB)
# Collecting pydantic-settings==2.12.0 (from -r requirements.txt (line 44))
#   Using cached pydantic_settings-2.12.0-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: typing_extensions==4.15.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from -r requirements.txt (line 45)) (4.15.0)
# Collecting ddgs==9.10.0 (from -r requirements.txt (line 50))
#   Using cached ddgs-9.10.0-py3-none-any.whl.metadata (12 kB)
# Collecting requests==2.32.5 (from -r requirements.txt (line 51))
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting beautifulsoup4==4.14.3 (from -r requirements.txt (line 52))
#   Using cached beautifulsoup4-4.14.3-py3-none-any.whl.metadata (3.8 kB)
# Collecting ipykernel==7.1.0 (from -r requirements.txt (line 57))
#   Using cached ipykernel-7.1.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting ipython==9.8.0 (from -r requirements.txt (line 58))
#   Using cached ipython-9.8.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting jupyterlab==4.5.1 (from -r requirements.txt (line 59))
#   Using cached jupyterlab-4.5.1-py3-none-any.whl.metadata (16 kB)
# Collecting numexpr==2.14.1 (from -r requirements.txt (line 64))
#   Using cached numexpr-2.14.1-cp311-cp311-win_amd64.whl.metadata (9.3 kB)
# Collecting google-search-results==2.4.2 (from -r requirements.txt (line 65))
#   Using cached google_search_results-2.4.2-py3-none-any.whl
# Collecting python-dotenv==1.2.1 (from -r requirements.txt (line 70))
#   Using cached python_dotenv-1.2.1-py3-none-any.whl.metadata (25 kB)
# Collecting tqdm==4.67.1 (from -r requirements.txt (line 71))
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting jsonpatch<2.0.0,>=1.33.0 (from langchain-core==1.2.2->-r requirements.txt (line 12))
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl.metadata (3.0 kB)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core==1.2.2->-r requirements.txt (line 12))
#   Using cached langsmith-0.9.4-py3-none-any.whl.metadata (21 kB)
# Collecting packaging<26.0.0,>=23.2.0 (from langchain-core==1.2.2->-r requirements.txt (line 12))
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from langchain-core==1.2.2->-r requirements.txt (line 12)) (6.0.3)
# Collecting tenacity!=8.4.0,<10.0.0,>=8.1.0 (from langchain-core==1.2.2->-r requirements.txt (line 12))
#   Using cached tenacity-9.1.4-py3-none-any.whl.metadata (1.2 kB)
# Collecting uuid-utils<1.0,>=0.12.0 (from langchain-core==1.2.2->-r requirements.txt (line 12))
#   Using cached uuid_utils-0.16.2-cp311-cp311-win_amd64.whl.metadata (6.5 kB)
# Collecting langgraph-sdk<0.4.0,>=0.3.0 (from langgraph==1.0.5->-r requirements.txt (line 23))
#   Using cached langgraph_sdk-0.3.15-py3-none-any.whl.metadata (1.7 kB)
# Collecting xxhash>=3.5.0 (from langgraph==1.0.5->-r requirements.txt (line 23))
#   Using cached xxhash-3.8.0-cp311-cp311-win_amd64.whl.metadata (15 kB)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint==3.0.1->-r requirements.txt (line 25))
#   Using cached ormsgpack-1.12.2-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# Collecting annotated-types>=0.6.0 (from pydantic==2.12.5->-r requirements.txt (line 43))
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.41.5 (from pydantic==2.12.5->-r requirements.txt (line 43))
#   Using cached pydantic_core-2.41.5-cp311-cp311-win_amd64.whl.metadata (7.4 kB)
# Collecting typing-inspection>=0.4.2 (from pydantic==2.12.5->-r requirements.txt (line 43))
#   Using cached typing_inspection-0.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting sqlalchemy<3.0.0,>=1.4.0 (from langchain-classic==1.0.0->-r requirements.txt (line 11))
#   Using cached sqlalchemy-2.0.51-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from requests==2.32.5->-r requirements.txt (line 51)) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from requests==2.32.5->-r requirements.txt (line 51)) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from requests==2.32.5->-r requirements.txt (line 51)) (2.7.0)
# Requirement already satisfied: certifi>=2017.4.17 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from requests==2.32.5->-r requirements.txt (line 51)) (2026.6.17)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community==0.4.1->-r requirements.txt (line 13))
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community==0.4.1->-r requirements.txt (line 13))
#   Using cached httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting numpy>=1.26.2 (from langchain-community==0.4.1->-r requirements.txt (line 13))
#   Using cached numpy-2.4.6-cp311-cp311-win_amd64.whl.metadata (6.6 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp==3.13.2->-r requirements.txt (line 37))
#   Using cached aiohappyeyeballs-2.6.2-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp==3.13.2->-r requirements.txt (line 37))
#   Using cached aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from aiohttp==3.13.2->-r requirements.txt (line 37)) (26.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp==3.13.2->-r requirements.txt (line 37))
#   Using cached frozenlist-1.8.0-cp311-cp311-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp==3.13.2->-r requirements.txt (line 37))
#   Using cached multidict-6.7.1-cp311-cp311-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp==3.13.2->-r requirements.txt (line 37))
#   Using cached propcache-0.5.2-cp311-cp311-win_amd64.whl.metadata (17 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp==3.13.2->-r requirements.txt (line 37))
#   Using cached yarl-1.24.2-cp311-cp311-win_amd64.whl.metadata (97 kB)
# Collecting distro<2,>=1.7.0 (from openai==2.13.0->-r requirements.txt (line 30))
#   Using cached distro-1.9.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jiter<1,>=0.10.0 (from openai==2.13.0->-r requirements.txt (line 30))
#   Using cached jiter-0.16.0-cp311-cp311-win_amd64.whl.metadata (5.3 kB)
# Collecting sniffio (from openai==2.13.0->-r requirements.txt (line 30))
#   Using cached sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting regex>=2022.1.18 (from tiktoken==0.12.0->-r requirements.txt (line 31))
#   Using cached regex-2026.6.28-cp311-cp311-win_amd64.whl.metadata (41 kB)
# Requirement already satisfied: httpcore==1.* in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from httpx==0.28.1->-r requirements.txt (line 36)) (1.0.9)
# Collecting click>=8.1.8 (from ddgs==9.10.0->-r requirements.txt (line 50))
#   Using cached click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting primp>=0.15.0 (from ddgs==9.10.0->-r requirements.txt (line 50))
#   Using cached primp-1.3.1-cp310-abi3-win_amd64.whl.metadata (3.8 kB)
# Collecting lxml>=4.9.4 (from ddgs==9.10.0->-r requirements.txt (line 50))
#   Using cached lxml-6.1.1-cp311-cp311-win_amd64.whl.metadata (3.6 kB)
# Collecting fake-useragent>=2.2.0 (from ddgs==9.10.0->-r requirements.txt (line 50))
#   Using cached fake_useragent-2.2.0-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: soupsieve>=1.6.1 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from beautifulsoup4==4.14.3->-r requirements.txt (line 52)) (2.8.4)
# Requirement already satisfied: comm>=0.1.1 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from ipykernel==7.1.0->-r requirements.txt (line 57)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from ipykernel==7.1.0->-r requirements.txt (line 57)) (1.8.21)
# Requirement already satisfied: jupyter-client>=8.0.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from ipykernel==7.1.0->-r requirements.txt (line 57)) (8.9.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from ipykernel==7.1.0->-r requirements.txt (line 57)) (5.9.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from ipykernel==7.1.0->-r requirements.txt (line 57)) (0.2.2)
# Collecting nest-asyncio>=1.4 (from ipykernel==7.1.0->-r requirements.txt (line 57))
#   Using cached nest_asyncio-1.6.0-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: psutil>=5.7 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from ipykernel==7.1.0->-r requirements.txt (line 57)) (7.2.2)
# Requirement already satisfied: pyzmq>=25 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from ipykernel==7.1.0->-r requirements.txt (line 57)) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from ipykernel==7.1.0->-r requirements.txt (line 57)) (6.5.7)
# Requirement already satisfied: traitlets>=5.4.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from ipykernel==7.1.0->-r requirements.txt (line 57)) (5.15.1)
# Requirement already satisfied: colorama>=0.4.4 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from ipython==9.8.0->-r requirements.txt (line 58)) (0.4.6)
# Requirement already satisfied: decorator>=4.3.2 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from ipython==9.8.0->-r requirements.txt (line 58)) (5.3.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from ipython==9.8.0->-r requirements.txt (line 58)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from ipython==9.8.0->-r requirements.txt (line 58)) (0.20.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from ipython==9.8.0->-r requirements.txt (line 58)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from ipython==9.8.0->-r requirements.txt (line 58)) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from ipython==9.8.0->-r requirements.txt (line 58)) (0.6.3)
# Requirement already satisfied: async-lru>=1.0.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 59)) (2.3.0)
# Requirement already satisfied: jinja2>=3.0.3 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 59)) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 59)) (2.3.1)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 59)) (2.20.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.28.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 59)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 59)) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyterlab==4.5.1->-r requirements.txt (line 59)) (65.5.0)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community==0.4.1->-r requirements.txt (line 13))
#   Using cached marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community==0.4.1->-r requirements.txt (line 13))
#   Using cached typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: h11>=0.16 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from httpcore==1.*->httpx==0.28.1->-r requirements.txt (line 36)) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core==1.2.2->-r requirements.txt (line 12)) (3.1.1)
# Requirement already satisfied: argon2-cffi>=21.1 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (7.17.1)
# Requirement already satisfied: nbformat>=5.3.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (0.25.0)
# Requirement already satisfied: pywinpty!=3.0.4,>=2.0.1 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (3.0.5)
# Requirement already satisfied: send2trash>=1.8.2 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (2.18.0)
# Requirement already satisfied: json5>=0.9.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (0.15.0)
# Requirement already satisfied: jsonschema>=4.18.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (4.26.0)
# Collecting orjson>=3.11.5 (from langgraph-sdk<0.4.0,>=0.3.0->langgraph==1.0.5->-r requirements.txt (line 23))
#   Using cached orjson-3.11.9-cp311-cp311-win_amd64.whl.metadata (43 kB)
# Collecting requests-toolbelt>=1.0.0 (from langsmith<1.0.0,>=0.3.45->langchain-core==1.2.2->-r requirements.txt (line 12))
#   Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting websockets>=15.0 (from langsmith<1.0.0,>=0.3.45->langchain-core==1.2.2->-r requirements.txt (line 12))
#   Using cached websockets-16.0-cp311-cp311-win_amd64.whl.metadata (7.0 kB)
# Collecting zstandard>=0.23.0 (from langsmith<1.0.0,>=0.3.45->langchain-core==1.2.2->-r requirements.txt (line 12))
#   Using cached zstandard-0.25.0-cp311-cp311-win_amd64.whl.metadata (3.3 kB)
# Requirement already satisfied: wcwidth in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython==9.8.0->-r requirements.txt (line 58)) (0.8.2)
# Collecting greenlet>=1 (from sqlalchemy<3.0.0,>=1.4.0->langchain-classic==1.0.0->-r requirements.txt (line 11))
#   Using cached greenlet-3.5.3-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community==0.4.1->-r requirements.txt (line 13))
#   Using cached mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: argon2-cffi-bindings in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (25.1.0)
# Collecting brotli (from httpx[brotli,http2,socks]>=0.28.1->ddgs==9.10.0->-r requirements.txt (line 50))
#   Using cached brotli-1.2.0-cp311-cp311-win_amd64.whl.metadata (6.3 kB)
# Collecting h2<5,>=3 (from httpx[brotli,http2,socks]>=0.28.1->ddgs==9.10.0->-r requirements.txt (line 50))
#   Using cached h2-4.3.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting socksio==1.* (from httpx[brotli,http2,socks]>=0.28.1->ddgs==9.10.0->-r requirements.txt (line 50))
#   Using cached socksio-1.0.0-py3-none-any.whl.metadata (6.1 kB)
# Collecting hyperframe<7,>=6.1 (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs==9.10.0->-r requirements.txt (line 50))
#   Using cached hyperframe-6.1.0-py3-none-any.whl.metadata (4.3 kB)
# Collecting hpack<5,>=4.1 (from h2<5,>=3->httpx[brotli,http2,socks]>=0.28.1->ddgs==9.10.0->-r requirements.txt (line 50))
#   Using cached hpack-4.2.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jedi>=0.18.1->ipython==9.8.0->-r requirements.txt (line 58)) (0.8.7)
# Requirement already satisfied: MarkupSafe>=2.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jinja2>=3.0.3->jupyterlab==4.5.1->-r requirements.txt (line 59)) (3.0.3)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (2026.6.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyter-client>=8.0.0->ipykernel==7.1.0->-r requirements.txt (line 57)) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel==7.1.0->-r requirements.txt (line 57)) (4.10.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (4.1.0)
# Requirement already satisfied: rfc3339-validator in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (0.1.1)
# Requirement already satisfied: fqdn in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (1.5.1)
# Requirement already satisfied: isoduration in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (20.11.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (1.1.0)
# Requirement already satisfied: uri-template in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (25.10.0)
# Requirement already satisfied: bleach!=5.0.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (6.4.0)
# Requirement already satisfied: defusedxml in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (3.3.2)
# Requirement already satisfied: nbclient>=0.5.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (0.11.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (1.5.1)
# Requirement already satisfied: webencodings in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (0.5.1)
# Requirement already satisfied: tinycss2>=1.1.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (2.21.2)
# Requirement already satisfied: six>=1.5 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel==7.1.0->-r requirements.txt (line 57)) (1.17.0)
# Requirement already satisfied: lark>=1.2.2 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (1.3.1)
# Requirement already satisfied: executing>=1.2.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from stack_data>=0.6.0->ipython==9.8.0->-r requirements.txt (line 58)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from stack_data>=0.6.0->ipython==9.8.0->-r requirements.txt (line 58)) (3.0.1)
# Requirement already satisfied: pure-eval in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from stack_data>=0.6.0->ipython==9.8.0->-r requirements.txt (line 58)) (0.2.3)
# Requirement already satisfied: cffi>=1.0.1 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (2.0.0)
# Requirement already satisfied: pycparser in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (3.0)
# Requirement already satisfied: arrow>=0.15.0 in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (1.4.0)
# Requirement already satisfied: tzdata in C:\25-Trainings\2-Confirmed\30-06-25-Agentic-AI-Acadwizz\venv\Lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.5.1->-r requirements.txt (line 59)) (2026.2)
# Using cached langchain-1.2.0-py3-none-any.whl (102 kB)
# Using cached langchain_core-1.2.2-py3-none-any.whl (476 kB)
# Using cached langgraph-1.0.5-py3-none-any.whl (157 kB)
# Using cached langgraph_prebuilt-1.0.5-py3-none-any.whl (35 kB)
# Using cached langgraph_checkpoint-3.0.1-py3-none-any.whl (46 kB)
# Using cached pydantic-2.12.5-py3-none-any.whl (463 kB)
# Using cached langchain_classic-1.0.0-py3-none-any.whl (1.0 MB)
# Using cached langchain_text_splitters-1.1.0-py3-none-any.whl (34 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# Using cached aiohttp-3.13.2-cp311-cp311-win_amd64.whl (456 kB)
# Using cached pydantic_settings-2.12.0-py3-none-any.whl (51 kB)
# Using cached langchain_openai-1.1.5-py3-none-any.whl (84 kB)
# Using cached openai-2.13.0-py3-none-any.whl (1.1 MB)
# Using cached tiktoken-0.12.0-cp311-cp311-win_amd64.whl (879 kB)
# Using cached anyio-4.12.0-py3-none-any.whl (113 kB)
# Using cached ddgs-9.10.0-py3-none-any.whl (40 kB)
# Using cached beautifulsoup4-4.14.3-py3-none-any.whl (107 kB)
# Using cached ipykernel-7.1.0-py3-none-any.whl (117 kB)
# Using cached ipython-9.8.0-py3-none-any.whl (621 kB)
# Using cached jupyterlab-4.5.1-py3-none-any.whl (12.4 MB)
# Using cached numexpr-2.14.1-cp311-cp311-win_amd64.whl (160 kB)
# Using cached python_dotenv-1.2.1-py3-none-any.whl (21 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached pydantic_core-2.41.5-cp311-cp311-win_amd64.whl (2.0 MB)
# Using cached dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Using cached httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Using cached jiter-0.16.0-cp311-cp311-win_amd64.whl (199 kB)
# Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Using cached langgraph_sdk-0.3.15-py3-none-any.whl (98 kB)
# Using cached langsmith-0.9.4-py3-none-any.whl (603 kB)
# Using cached marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Using cached multidict-6.7.1-cp311-cp311-win_amd64.whl (45 kB)
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Using cached sqlalchemy-2.0.51-cp311-cp311-win_amd64.whl (2.1 MB)
# Using cached tenacity-9.1.4-py3-none-any.whl (28 kB)
# Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Using cached uuid_utils-0.16.2-cp311-cp311-win_amd64.whl (176 kB)
# Using cached yarl-1.24.2-cp311-cp311-win_amd64.whl (92 kB)
# Using cached aiohappyeyeballs-2.6.2-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Using cached click-8.4.2-py3-none-any.whl (119 kB)
# Using cached fake_useragent-2.2.0-py3-none-any.whl (161 kB)
# Using cached frozenlist-1.8.0-cp311-cp311-win_amd64.whl (44 kB)
# Using cached greenlet-3.5.3-cp311-cp311-win_amd64.whl (239 kB)
# Using cached h2-4.3.0-py3-none-any.whl (61 kB)
# Using cached hpack-4.2.0-py3-none-any.whl (34 kB)
# Using cached hyperframe-6.1.0-py3-none-any.whl (13 kB)
# Using cached socksio-1.0.0-py3-none-any.whl (12 kB)
# Using cached lxml-6.1.1-cp311-cp311-win_amd64.whl (4.0 MB)
# Using cached mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Using cached nest_asyncio-1.6.0-py3-none-any.whl (5.2 kB)
# Using cached numpy-2.4.6-cp311-cp311-win_amd64.whl (12.6 MB)
# Using cached orjson-3.11.9-cp311-cp311-win_amd64.whl (127 kB)
# Using cached ormsgpack-1.12.2-cp311-cp311-win_amd64.whl (117 kB)
# Using cached primp-1.3.1-cp310-abi3-win_amd64.whl (4.7 MB)
# Using cached propcache-0.5.2-cp311-cp311-win_amd64.whl (42 kB)
# Using cached regex-2026.6.28-cp311-cp311-win_amd64.whl (277 kB)
# Using cached requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
# Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Using cached websockets-16.0-cp311-cp311-win_amd64.whl (178 kB)
# Using cached xxhash-3.8.0-cp311-cp311-win_amd64.whl (32 kB)
# Using cached zstandard-0.25.0-cp311-cp311-win_amd64.whl (506 kB)
# Using cached brotli-1.2.0-cp311-cp311-win_amd64.whl (369 kB)
# Installing collected packages: brotli, zstandard, xxhash, websockets, uuid-utils, typing-inspection, tqdm, tenacity, socksio, sniffio, requests, regex, python-dotenv, pydantic-core, propcache, primp, packaging, ormsgpack, orjson, numpy, nest-asyncio, mypy-extensions, multidict, lxml, jsonpatch, jiter, hyperframe, httpx-sse, hpack, greenlet, frozenlist, fake-useragent, distro, click, beautifulsoup4, anyio, annotated-types, aiohappyeyeballs, yarl, typing-inspect, tiktoken, sqlalchemy, requests-toolbelt, pydantic, numexpr, marshmallow, ipython, h2, google-search-results, aiosignal, pydantic-settings, openai, langsmith, langgraph-sdk, ipykernel, dataclasses-json, aiohttp, langchain-core, ddgs, langgraph-checkpoint, langchain-text-splitters, langchain-openai, langgraph-prebuilt, langchain-classic, langgraph, langchain-community, langchain, jupyterlab
#
#     ---------------------------------------  1/68 [zstandard]
#    - --------------------------------------  2/68 [xxhash]
#    - --------------------------------------  3/68 [websockets]
#    - --------------------------------------  3/68 [websockets]
#    - --------------------------------------  3/68 [websockets]
#    - --------------------------------------  3/68 [websockets]
#    - --------------------------------------  3/68 [websockets]
#    - --------------------------------------  3/68 [websockets]
#    - --------------------------------------  3/68 [websockets]
#    - --------------------------------------  3/68 [websockets]
#    - --------------------------------------  3/68 [websockets]
#    - --------------------------------------  3/68 [websockets]
#    - --------------------------------------  3/68 [websockets]
#    - --------------------------------------  3/68 [websockets]
#    -- -------------------------------------  5/68 [typing-inspection]
#    --- ------------------------------------  6/68 [tqdm]
#    --- ------------------------------------  6/68 [tqdm]
#    --- ------------------------------------  6/68 [tqdm]
#    --- ------------------------------------  6/68 [tqdm]
#    --- ------------------------------------  6/68 [tqdm]
#    --- ------------------------------------  6/68 [tqdm]
#    --- ------------------------------------  6/68 [tqdm]
#    ---- -----------------------------------  7/68 [tenacity]
#    ---- -----------------------------------  7/68 [tenacity]
#    ---- -----------------------------------  7/68 [tenacity]
#    ---- -----------------------------------  8/68 [socksio]
#    ----- ----------------------------------  9/68 [sniffio]
#   Attempting uninstall: requests
#    ----- ----------------------------------  9/68 [sniffio]
#     Found existing installation: requests 2.34.2
#    ----- ----------------------------------  9/68 [sniffio]
#     Uninstalling requests-2.34.2:
#    ----- ----------------------------------  9/68 [sniffio]
#    ----- ---------------------------------- 10/68 [requests]
#       Successfully uninstalled requests-2.34.2
#    ----- ---------------------------------- 10/68 [requests]
#    ----- ---------------------------------- 10/68 [requests]
#    ----- ---------------------------------- 10/68 [requests]
#    ----- ---------------------------------- 10/68 [requests]
#    ------ --------------------------------- 11/68 [regex]
#    ------ --------------------------------- 11/68 [regex]
#    ------ --------------------------------- 11/68 [regex]
#    ------- -------------------------------- 12/68 [python-dotenv]
#    ------- -------------------------------- 12/68 [python-dotenv]
#    ------- -------------------------------- 13/68 [pydantic-core]
#    -------- ------------------------------- 14/68 [propcache]
#    -------- ------------------------------- 15/68 [primp]
#   Attempting uninstall: packaging
#    -------- ------------------------------- 15/68 [primp]
#     Found existing installation: packaging 26.2
#    -------- ------------------------------- 15/68 [primp]
#     Uninstalling packaging-26.2:
#    -------- ------------------------------- 15/68 [primp]
#       Successfully uninstalled packaging-26.2
#    -------- ------------------------------- 15/68 [primp]
#    --------- ------------------------------ 16/68 [packaging]
#    --------- ------------------------------ 16/68 [packaging]
#    --------- ------------------------------ 16/68 [packaging]
#    --------- ------------------------------ 16/68 [packaging]
#    ---------- ----------------------------- 17/68 [ormsgpack]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ----------- ---------------------------- 19/68 [numpy]
#    ------------ --------------------------- 22/68 [multidict]
#    ------------- -------------------------- 23/68 [lxml]
#    ------------- -------------------------- 23/68 [lxml]
#    ------------- -------------------------- 23/68 [lxml]
#    ------------- -------------------------- 23/68 [lxml]
#    ------------- -------------------------- 23/68 [lxml]
#    ------------- -------------------------- 23/68 [lxml]
#    ------------- -------------------------- 23/68 [lxml]
#    ------------- -------------------------- 23/68 [lxml]
#    ------------- -------------------------- 23/68 [lxml]
#    ------------- -------------------------- 23/68 [lxml]
#    -------------- ------------------------- 24/68 [jsonpatch]
#    -------------- ------------------------- 25/68 [jiter]
#    --------------- ------------------------ 26/68 [hyperframe]
#    --------------- ------------------------ 27/68 [httpx-sse]
#    ---------------- ----------------------- 28/68 [hpack]
#    ---------------- ----------------------- 28/68 [hpack]
#    ---------------- ----------------------- 28/68 [hpack]
#    ----------------- ---------------------- 29/68 [greenlet]
#    ----------------- ---------------------- 29/68 [greenlet]
#    ----------------- ---------------------- 29/68 [greenlet]
#    ----------------- ---------------------- 29/68 [greenlet]
#    ----------------- ---------------------- 29/68 [greenlet]
#    ----------------- ---------------------- 29/68 [greenlet]
#    ------------------ --------------------- 31/68 [fake-useragent]
#    ------------------ --------------------- 32/68 [distro]
#    ------------------- -------------------- 33/68 [click]
#    ------------------- -------------------- 33/68 [click]
#    ------------------- -------------------- 33/68 [click]
#    ------------------- -------------------- 33/68 [click]
#    ------------------- -------------------- 33/68 [click]
#   Attempting uninstall: beautifulsoup4
#    ------------------- -------------------- 33/68 [click]
#     Found existing installation: beautifulsoup4 4.15.0
#    ------------------- -------------------- 33/68 [click]
#     Uninstalling beautifulsoup4-4.15.0:
#    ------------------- -------------------- 33/68 [click]
#       Successfully uninstalled beautifulsoup4-4.15.0
#    ------------------- -------------------- 33/68 [click]
#    -------------------- ------------------- 34/68 [beautifulsoup4]
#    -------------------- ------------------- 34/68 [beautifulsoup4]
#    -------------------- ------------------- 34/68 [beautifulsoup4]
#    -------------------- ------------------- 34/68 [beautifulsoup4]
#   Attempting uninstall: anyio
#    -------------------- ------------------- 34/68 [beautifulsoup4]
#     Found existing installation: anyio 4.14.1
#    -------------------- ------------------- 34/68 [beautifulsoup4]
#    -------------------- ------------------- 35/68 [anyio]
#     Uninstalling anyio-4.14.1:
#    -------------------- ------------------- 35/68 [anyio]
#       Successfully uninstalled anyio-4.14.1
#    -------------------- ------------------- 35/68 [anyio]
#    -------------------- ------------------- 35/68 [anyio]
#    -------------------- ------------------- 35/68 [anyio]
#    -------------------- ------------------- 35/68 [anyio]
#    -------------------- ------------------- 35/68 [anyio]
#    -------------------- ------------------- 35/68 [anyio]
#    -------------------- ------------------- 35/68 [anyio]
#    -------------------- ------------------- 35/68 [anyio]
#    -------------------- ------------------- 35/68 [anyio]
# ...
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 65/68 [langchain-community]
#    -------------------------------------- - 66/68 [langchain]
#    -------------------------------------- - 66/68 [langchain]
#    -------------------------------------- - 66/68 [langchain]
#    -------------------------------------- - 66/68 [langchain]
#    -------------------------------------- - 66/68 [langchain]
#    -------------------------------------- - 66/68 [langchain]
#    -------------------------------------- - 66/68 [langchain]
#   Attempting uninstall: jupyterlab
#    -------------------------------------- - 66/68 [langchain]
#    ---------------------------------------  67/68 [jupyterlab]
#     Found existing installation: jupyterlab 4.6.1
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#     Uninstalling jupyterlab-4.6.1:
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#       Successfully uninstalled jupyterlab-4.6.1
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------  67/68 [jupyterlab]
#    ---------------------------------------- 68/68 [jupyterlab]
#
# Successfully installed aiohappyeyeballs-2.6.2 aiohttp-3.13.2 aiosignal-1.4.0 annotated-types-0.7.0 anyio-4.12.0 beautifulsoup4-4.14.3 brotli-1.2.0 click-8.4.2 dataclasses-json-0.6.7 ddgs-9.10.0 distro-1.9.0 fake-useragent-2.2.0 frozenlist-1.8.0 google-search-results-2.4.2 greenlet-3.5.3 h2-4.3.0 hpack-4.2.0 httpx-sse-0.4.3 hyperframe-6.1.0 ipykernel-7.1.0 ipython-9.8.0 jiter-0.16.0 jsonpatch-1.33 jupyterlab-4.5.1 langchain-1.2.0 langchain-classic-1.0.0 langchain-community-0.4.1 langchain-core-1.2.2 langchain-openai-1.1.5 langchain-text-splitters-1.1.0 langgraph-1.0.5 langgraph-checkpoint-3.0.1 langgraph-prebuilt-1.0.5 langgraph-sdk-0.3.15 langsmith-0.9.4 lxml-6.1.1 marshmallow-3.26.2 multidict-6.7.1 mypy-extensions-1.1.0 nest-asyncio-1.6.0 numexpr-2.14.1 numpy-2.4.6 openai-2.13.0 orjson-3.11.9 ormsgpack-1.12.2 packaging-25.0 primp-1.3.1 propcache-0.5.2 pydantic-2.12.5 pydantic-core-2.41.5 pydantic-settings-2.12.0 python-dotenv-1.2.1 regex-2026.6.28 requests-2.32.5 requests-toolbelt-1.0.0 sniffio-1.3.1 socksio-1.0.0 sqlalchemy-2.0.51 tenacity-9.1.4 tiktoken-0.12.0 tqdm-4.67.1 typing-inspect-0.9.0 typing-inspection-0.4.2 uuid-utils-0.16.2 websockets-16.0 xxhash-3.8.0 yarl-1.24.2 zstandard-0.25.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# notebook 7.6.0 requires jupyterlab<4.7,>=4.6.0, but you have jupyterlab 4.5.1 which is incompatible.

# %%
import sys

print("Python version:", sys.version)

major, minor = sys.version_info[:2]
assert major == 3 and minor == 11, f"Python 3.11.x is required (found {major}.{minor})"
print("✅ Python version OK")
# Out:
# Python version: 3.11.0 (main, Oct 24 2022, 18:26:48) [MSC v.1933 64 bit (AMD64)]
# ✅ Python version OK

# %%
import importlib.metadata as md

EXPECTED_VERSIONS = {
    "langchain": "1.2.0",
    "langchain-classic": "1.0.0",
    "langchain-core": "1.2.2",
    "langchain-community": "0.4.1",
    "langchain-openai": "1.1.5",
    "langgraph": "1.0.5",
    "openai": "2.13.0",
    "pydantic": "2.12.5",
    "typing-extensions": "4.15.0",
}

# %%
errors = False

for pkg, expected in EXPECTED_VERSIONS.items():
    installed = md.version(pkg)
    print(f"{pkg:25} installed={installed} expected={expected}")
    if installed != expected:
        errors = True
# Out:
# langchain                 installed=1.2.0 expected=1.2.0
# langchain-core            installed=1.2.2 expected=1.2.2
# langchain-community       installed=0.4.1 expected=0.4.1
# langchain-openai          installed=1.1.5 expected=1.1.5
# langgraph                 installed=1.0.5 expected=1.0.5
# openai                    installed=2.13.0 expected=2.13.0
# pydantic                  installed=2.12.5 expected=2.12.5
# typing-extensions         installed=4.15.0 expected=4.15.0

# %%
assert not errors, "❌ Version mismatch detected"
print("✅ All critical package versions match exactly")
# Out:
# ✅ All critical package versions match exactly

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.callbacks import StdOutCallbackHandler

print("✅ Core LangChain imports successful")
# Out:
# ✅ Core LangChain imports successful

# %%
from langchain_core.prompts import ChatPromptTemplate

prompt_template = ChatPromptTemplate.from_template("""
You are an expert web researcher. Your goal is to provide a comprehensive answer.

Question:
{input}

Final Answer:
""")

# %%
import os
from dotenv import load_dotenv

# Load the API key from the .env file
dotenv_path = os.path.expanduser("~/dev.env")
load_dotenv(dotenv_path, override=True)

print("Dependencies installed and environment loaded.")
# Out:
# Dependencies installed and environment loaded.

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4o-mini",
    temperature=0
)

print("✅ LLM initialized")
# Out:
# ✅ LLM initialized

# %%
from langchain_core.output_parsers import StrOutputParser
from langchain_core.callbacks import StdOutCallbackHandler

callbacks = [StdOutCallbackHandler()]

chain = (
    prompt_template
    | llm.with_config({"callbacks": callbacks})
    | StrOutputParser()
)

print("✅ LangChain pipeline constructed")
# Out:
# ✅ LangChain pipeline constructed

# %%
from IPython.display import display, Markdown

topic = "Explain why LangChain moved agent execution to LangGraph"

response = chain.invoke({"input": topic})

print("\n--- Final Output (Markdown) ---")
display(Markdown(response))
# Out:
# --- Final Output (Markdown) ---
# LangChain's decision to move agent execution to LangGraph is rooted in several strategic and technical considerations aimed at enhancing the functionality, efficiency, and scalability of their framework for building applications powered by language models. Here are the key reasons for this transition:
#
# 1. **Improved Modularity**: By integrating agent execution into LangGraph, LangChain can offer a more modular architecture. This allows developers to build and customize their applications more easily, as they can leverage the graph structure to connect various components and functionalities without being tightly coupled.
#
# 2. **Enhanced Performance**: LangGraph is designed to optimize the execution of complex workflows. By moving agent execution to this framework, LangChain can take advantage of more efficient data handling and processing capabilities, leading to faster response times and improved overall performance of applications.
#
# 3. **Better Visualization and Debugging**: LangGraph provides a visual representation of the execution flow, making it easier for developers to understand and debug their applications. This transparency is crucial for identifying bottlenecks or issues in the agent's decision-making process, ultimately leading to more robust applications.
#
# 4. **Scalability**: As applications grow in complexity, the need for a scalable solution becomes paramount. LangGraph is built to handle larger and more intricate workflows, allowing LangChain to support more sophisticated use cases without compromising performance or reliability.
#
# 5. **Integration with Other Tools**: LangGraph facilitates better integration with other tools and libraries within the LangChain ecosystem. This interoperability allows developers to leverage existing resources and functionalities, streamlining the development process and enhancing the capabilities of their applications.
#
# 6. **Support for Advanced Features**: The move to LangGraph enables LangChain to implement advanced features such as dynamic agent behavior, real-time updates, and more complex decision-making processes. This flexibility is essential for creating applications that can adapt to changing inputs and user needs.
#
# 7. **Community and Ecosystem Growth**: By adopting LangGraph for agent execution, LangChain can foster a more vibrant community around its framework. Developers can contribute to and build upon the graph-based architecture, leading to a richer ecosystem of tools, libraries, and shared knowledge.
#
# In summary, the transition of agent execution to LangGraph represents a strategic enhancement for LangChain, focusing on modularity, performance, scalability, and community engagement. This move positions LangChain to better meet the evolving needs of developers and users in the rapidly advancing field of language model applications.

# %%
pip freeze | sort
# Out:
# aiohappyeyeballs==2.6.1
# aiohttp==3.13.2
# aiosignal==1.4.0
# aiosqlite==0.22.0
# annotated-types==0.7.0
# anyio==4.12.0
# argon2-cffi-bindings==25.1.0
# argon2-cffi==25.1.0
# arrow==1.4.0
# asttokens==3.0.1
# async-lru==2.0.5
# attrs==25.4.0
# babel==2.17.0
# beautifulsoup4==4.14.3
# bleach==6.3.0
# brotli==1.2.0
# cachetools==6.2.4
# certifi==2025.11.12
# cffi==2.0.0
# charset-normalizer==3.4.4
# click==8.3.1
# colorama==0.4.6
# comm==0.2.3
# dataclasses-json==0.6.7
# ddgs==9.10.0
# debugpy==1.8.19
# decorator==5.2.1
# defusedxml==0.7.1
# distro==1.9.0
# executing==2.2.1
# fake-useragent==2.2.0
# fastjsonschema==2.21.2
# filetype==1.2.0
# fqdn==1.5.1
# frozenlist==1.8.0
# google-auth==2.45.0
# google-genai==1.56.0
# greenlet==3.3.0
# h11==0.16.0
# h2==4.3.0
# hpack==4.1.0
# httpcore==1.0.9
# httpx-sse==0.4.3
# httpx==0.28.1
# hyperframe==6.1.0
# idna==3.11
# ipykernel==7.1.0
# ipython_pygments_lexers==1.1.1
# ipython==9.8.0
# ipywidgets==8.1.8
# isoduration==20.11.0
# jedi==0.19.2
# Jinja2==3.1.6
# jiter==0.12.0
# json5==0.12.1
# jsonpatch==1.33
# jsonpointer==3.0.0
# jsonschema-specifications==2025.9.1
# jsonschema==4.25.1
# jupyter-console==6.6.3
# jupyter-events==0.12.0
# jupyter-lsp==2.3.0
# jupyter_client==8.7.0
# jupyter_core==5.9.1
# jupyter_server_terminals==0.5.3
# jupyter_server==2.17.0
# jupyter==1.1.1
# jupyterlab_pygments==0.3.0
# jupyterlab_server==2.28.0
# jupyterlab_widgets==3.0.16
# jupyterlab==4.5.1
# langchain-classic==1.0.0
# langchain-community==0.4.1
# langchain-core==1.2.2
# langchain-google-genai==4.1.1
# langchain-openai==1.1.5
# langchain-text-splitters==1.1.0
# langchain==1.2.0
# langgraph-checkpoint-sqlite==3.0.1
# langgraph-checkpoint==3.0.1
# langgraph-prebuilt==1.0.5
# langgraph-sdk==0.3.0
# langgraph==1.0.5
# langsmith==0.5.0
# lark==1.3.1
# lxml==6.0.2
# MarkupSafe==3.0.3
# marshmallow==3.26.1
# matplotlib-inline==0.2.1
# mistune==3.1.4
# multidict==6.7.0
# mypy_extensions==1.1.0
# nbclient==0.10.2
# nbconvert==7.16.6
# nbformat==5.10.4
# nest-asyncio==1.6.0
# notebook_shim==0.2.4
# notebook==7.5.1
# numpy==2.3.5
# openai==2.13.0
# orjson==3.11.5
# ormsgpack==1.12.1
# overrides==7.7.0
# packaging==25.0
# pandocfilters==1.5.1
# parso==0.8.5
# platformdirs==4.5.1
# primp==0.15.0
# prometheus_client==0.23.1
# prompt_toolkit==3.0.52
# propcache==0.4.1
# psutil==7.1.3
# pure_eval==0.2.3
# pyasn1_modules==0.4.2
# pyasn1==0.6.1
# pycparser==2.23
# pydantic-settings==2.12.0
# pydantic_core==2.41.5
# pydantic==2.12.5
# Pygments==2.19.2
# python-dateutil==2.9.0.post0
# python-dotenv==1.2.1
# python-json-logger==4.0.0
# pywinpty==3.0.2
# PyYAML==6.0.3
# pyzmq==27.1.0
# referencing==0.37.0
# regex==2025.11.3
# requests-toolbelt==1.0.0
# requests==2.32.5
# rfc3339-validator==0.1.4
# rfc3986-validator==0.1.1
# rfc3987-syntax==1.1.0
# rpds-py==0.30.0
# rsa==4.9.1
# Send2Trash==1.8.3
# six==1.17.0
# sniffio==1.3.1
# socksio==1.0.0
# soupsieve==2.8
# SQLAlchemy==2.0.45
# sqlite-vec==0.1.6
# stack-data==0.6.3
# tenacity==9.1.2
# terminado==0.18.1
# tiktoken==0.12.0
# tinycss2==1.4.0
# tornado==6.5.4
# tqdm==4.67.1
# traitlets==5.14.3
# typing-inspect==0.9.0
# typing-inspection==0.4.2
# typing_extensions==4.15.0
# tzdata==2025.3
# uri-template==1.3.0
# urllib3==2.6.2
# uuid_utils==0.12.0
# wcwidth==0.2.14
# webcolors==25.10.0
# webencodings==0.5.1
# websocket-client==1.9.0
# websockets==15.0.1
# widgetsnbextension==4.0.15
# xxhash==3.6.0
# yarl==1.22.0
# zstandard==0.25.0
# Note: you may need to restart the kernel to use updated packages.
